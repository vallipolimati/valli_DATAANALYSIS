# %% [markdown]
# Pandas:
# 1.   used for data manipulation (data cleaning,organizing data)
# 2.   creates dataframes from excel,csv,txt,DBs
# 3.  Dataframe (rows and columns readable by python)
# 4. data cleaning by dropping or replacing with mean
# 5. visualize the data

# %%
import pandas as pd

# %%
names=['valli','priya','sasi','lavanya','fathima']
index=[40,42,42,43,45]
seri=pd.Series(names,index)
print(seri)
# Out:
# 40      valli
# 42      priya
# 42       sasi
# 43    lavanya
# 45    fathima
# dtype: object

# %% [markdown]
# Importing files
# *   for csv and txt: read_csv
# *   for excel: read_excel

# %%
df=pd.read_csv("/content/census2011.csv") #for reading the csv file

# %%
df.head(10)
# Out:
#    Ranking                    District        State  Population   Growth  \
# 0        1                       Thane  Maharashtra  11,060,148  36.01 %
# 1        2  North Twenty Four Parganas  West Bengal  10,009,781  12.04 %
# 2        3                   Bangalore    Karnataka   9,621,551  47.18 %
# 3        4                        Pune  Maharashtra   9,429,408  30.37 %
# 4        5             Mumbai Suburban  Maharashtra   9,356,962   8.29 %
# 5        6  South Twenty Four Parganas  West Bengal   8,161,961  18.17 %
# 6        7                  Barddhaman  West Bengal   7,717,563  11.92 %
# 7        8                   Ahmadabad      Gujarat   7,214,225  24.03 %
# 8        9                 Murshidabad  West Bengal   7,103,807  21.09 %
# 9       10                      Jaipur    Rajasthan   6,626,178  26.19 %
#
#    Sex-Ratio  Literacy
# 0        886     84.53
# 1        955     84.06
# 2        916     87.67
# 3        915     86.15
# 4        860     89.91
# 5        956     77.51
# 6        945     76.21
# 7        904     85.31
# 8        958     66.59
# 9        910     75.51

# %%
df.tail(10)
# Out:
#      Ranking         District                        State Population  \
# 600      631              Diu                Daman and Diu     52,074
# 601      632         Longleng                     Nagaland     50,484
# 602      633           Tawang            Arunachal Pradesh     49,977
# 603      634     North Sikkim                       Sikkim     43,709
# 604      635             Mahe                   Puducherry     41,816
# 605      636         Nicobars  Andaman and Nicobar Islands     36,842
# 606      637      Upper Siang            Arunachal Pradesh     35,320
# 607      638  Lahul and Spiti             Himachal Pradesh     31,564
# 608      639            Anjaw            Arunachal Pradesh     21,167
# 609      640    Dibang Valley            Arunachal Pradesh      8,004
#
#        Growth  Sex-Ratio  Literacy
# 600   17.77 %       1031     83.46
# 601  -21.57 %        905     72.17
# 602   28.40 %        714     59.00
# 603    6.53 %        767     78.01
# 604   13.54 %       1184     97.87
# 605  -12.42 %        777     78.06
# 606    5.87 %        889     59.99
# 607   -5.00 %        903     76.81
# 608   14.19 %        839     56.46
# 609   10.07 %        813     64.10

# %%
dft=pd.read_csv("/content/grades.txt",sep=" ") #for reading text file

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
dfe=pd.read_excel("/content/census2011.xlsx") #excel file reading

# %%
dfe.head()
# Out:
#    Ranking                    District        State  Population   Growth  \
# 0        1                       Thane  Maharashtra  11,060,148  36.01 %
# 1        2  North Twenty Four Parganas  West Bengal  10,009,781  12.04 %
# 2        3                   Bangalore    Karnataka   9,621,551  47.18 %
# 3        4                        Pune  Maharashtra   9,429,408  30.37 %
# 4        5             Mumbai Suburban  Maharashtra   9,356,962   8.29 %
#
#    Sex-Ratio  Literacy
# 0        886     84.53
# 1        955     84.06
# 2        916     87.67
# 3        915     86.15
# 4        860     89.91

# %%
dft=pd.read_csv("/content/grades.txt", sep = " ")
print(dft.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B>

# %%
df=pd.read_csv("/content/census2011.csv")
print(df.shape) #shape of rows and columns
print(df.shape[0]) #display shape of rows
print(df.shape[1]) #diplay shape of columns
# Out:
# (610, 7)
# 610
# 7

# %%
print(dft.columns)
# Out:
# Index(['Names Initials SEM1 SEM2 SEM3 Grade'], dtype='object')

# %% [markdown]
# Accessing Data:
#
#
# *   loc-accepts column names and index
# *   iloc-accepts only index

# %%
print(df[2:5]) #to access rows
# Out:
#    Ranking         District        State Population   Growth  Sex-Ratio  \
# 2        3        Bangalore    Karnataka  9,621,551  47.18 %        916
# 3        4             Pune  Maharashtra  9,429,408  30.37 %        915
# 4        5  Mumbai Suburban  Maharashtra  9,356,962   8.29 %        860
#
#    Literacy
# 2     87.67
# 3     86.15
# 4     89.91

# %%
print(dft.loc[2:5,"Names"]) #rows of specified columns
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5,:3]) #iloc[row range,column range]=>index
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull().head(7) #to check the nulls in the specified rows
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
dfn.isnull().sum() #to find the  no of nulls in each column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum() #to view total nulls
# Out:
# 4

# %%
dfc=dfn.dropna() #drops the rows which have nulls

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(5)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Cleaning with mean

# %%
m=dfn['SEM3'].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(m)
dfc2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dropped=dfc2.drop_duplicates()
print(dropped)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Columns

# %%
dfc2.rename(columns={"Grade":"GPA"}) #df.rename(columns={old:new})
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0      Joe        K   9.8  10.0   9.9  A+       1
# 1   Rajesh        M   8.9   9.1   9.3   A       1
# 2   Kissan        V   9.9   9.8  10.0   A       0
# 3     Mary        N   7.7   8.0   9.1   B       0
# 4     Jeen        K   9.8   9.1   9.9  A+       1
# 5      Raj        M   8.9   9.1   9.3   A       1
# 6   Hassan        V   9.9   9.0   9.2   A       1
# 7     Mari        N   7.7   8.0   7.1   B       1
# 8     Jess        K   9.1   9.1   9.9  A+       1
# 9   Rajini        M   9.1   9.1   9.3   A       0
# 10   Kiran        V   9.1   9.3   9.2   A       0
# 11    Maya        N   7.7   8.0   7.1   B       0
# 12   Jolin        K   9.8   9.1   9.9  A+       1
# 13  Rajesh        M   8.9   9.1   9.3   A       1
# 14    Riya        M   9.3   9.9  10.0   A       1
# 15    Sana        V   9.9   9.3   9.2   A       0
# 16    Mark        N   7.7   8.0   7.0   B       0

# %%
dfc2.rename(columns={"Grade":"GPA"},inplace=True)

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0     Joe        K   9.8  10.0   9.9  A+       1
# 1  Rajesh        M   8.9   9.1   9.3   A       1
# 2  Kissan        V   9.9   9.8  10.0   A       0
# 3    Mary        N   7.7   8.0   9.1   B       0
# 4    Jeen        K   9.8   9.1   9.9  A+       1

# %%
dfc2['Avg_score']=(dfc2['SEM1']+dfc2['SEM2']+dfc2['SEM3'])/3 #df['newcol']=values

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9  A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3   A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0   A       0   9.900000
# 3    Mary        N   7.7   8.0   9.1   B       0   8.266667
# 4    Jeen        K   9.8   9.1   9.9  A+       1   9.600000

# %%
dfc2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x="Names",y="SEM1",data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Placed"
)

# %% [markdown]
# Load diabets.csv
# create a relplot with age in the x axis and class as columns

# %%
dfd=pd.read_csv("/content/diabetcsv.csv")
dfd.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
dfd
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dfd['index']=(range(0,768))
sns.relplot(
    data=dfd,
    x="index",y="age",col="class"
)

# %% [markdown]
# Seaborn inbuilt datasets
# 1.  tips
# 2. dowjones
# 3. fmri
# 4. dots
# 5. healthexp
# To load dataset use
# =>load_dataset("dataset_name")

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
dots=sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
healthexp=sns.load_dataset("healthexp")
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
tips.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(data=tips,x="total_bill",y="smoker")

# %%
pl=sns.lineplot(x='total_bill',y='tip',data=tips)

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker')

# %% [markdown]
# creating difference based on a column via colours

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='time')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='day')

# %% [markdown]
# style- uses for different markers for different categories
# hue- different colour for diff category

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='size',style='day',palette='bright')

# %% [markdown]
# Colour Palette
# ->Pastel
# ->Bright
# ->dark
# ->muted
# ->colour blind
# ->deep

# %% [markdown]
# kind
# line

# %%
tips=sns.load_dataset("dowjones")
tips.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=tips,x="Date",y="Price",kind="line",color='m')

# %%
#subject=patient name ,region=brain location,

# %%
tips=sns.load_dataset("fmri")
tips.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=tips,x="timepoint",y="signal",kind="line",color='m')

# %%
sns.catplot(data=fmri,x="region",y="timepoint",color="c")

# %%
sns.catplot(data=tips,x="total_bill",y="time",kind="violin",hue="smoker")

# %% [markdown]
# *  plot the points
# *   fit the line
# *  select the line with least difference(linear fit)
# *   implot to create a function

# %%
sns.lmplot(x='size',y='tip',data=tips);

# %% [markdown]
# Web scrapping:
# *   Loading data from websites
# *   unstrucutred in HTML
# *   convertible into spresadsheets/DB
# *   Major websites have their APIs for web scrapping
# Purpose of scrabber:
# *   Extract all the data on particular sites
# *   Specific data that a user wants
# Process:
# *  URL
# *  Elements
# *   Scrapes the required data
# *   saves it in required format(csv,xlsx,Json)
# Applications:
# *   Email marketing
# *   Sentiment Analysis
# *   New monitoring
# *   Market Research
# *   Price Monitoring
